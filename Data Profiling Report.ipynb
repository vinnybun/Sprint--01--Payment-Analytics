# %%
#import libdraries
import pandas as pd

#load the dataset
df = pd.read_csv("payflow_dataset.csv")

#Display the first 5 rows of the dataset
print("The First 5 rows of the dataset","\n",df.head())
# Out:
# The First 5 rows of the dataset
#     step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
# Display an overview of the data
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB
# None

# %%
#Display the memory usage 
print(df.info(memory_usage="deep"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 1.4 GB
# None

# %%
#Display the missing values of each column
print(df.isna().sum())
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
#Check for Duplicates
print(df.duplicated().sum())
# Out:
# 0

# %%
#Display the datatypes of each column
print(df.dtypes)
# Out:
# step                int64
# type               object
# amount            float64
# nameOrig           object
# oldbalanceOrg     float64
# newbalanceOrig    float64
# nameDest           object
# oldbalanceDest    float64
# newbalanceDest    float64
# isFraud             int64
# isFlaggedFraud      int64
# dtype: object

# %% [markdown]
# ### Column Classification
#
#
# COLUMN | DATATYPE | BUSINESS NAME | POTENTIAL USE
# :--- | :--- | :--- | :---
# step | integer | Transaction time | Payment monitoring
# type | category | Transaction type | Customer Analytics
# amount | float | Transaction amount | Fraud detection
# nameOrig | Nominal | Customer | Customer Analytics
# oldbalanceOrg | float | Customer's pre-transaction balance | Payment Monitoring
# newbalanceOrg | float | Customer's post-transaction balance | Payment Monitoring
# nameDest | Nominal | Payment Recipient | Customer Analytics
# oldbalanceOrg | float | Non-merchant pre-transaction balance | Payment monitoring
# newbalanceOrg | float | Non-merchant post-transaction balance | Payment Monitoring
# isFraud | integer | Fraudulent transactions | Fraud Detection
# isFlaggedFraud | integer | Fraud Detector | Fraud Detection

# %%
 #SORT THE DATASET BY TRANSACTION AND CHECK FOR ANY OBSERVATIONS
df_amount = df.sort_values(by= "amount", ascending=False)
print(df_amount)
# Out:
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 3686583   276  TRANSFER  92445516.64  C1715283297            0.0
# 4060598   300  TRANSFER  73823490.36  C2127282686            0.0
# 4146397   303  TRANSFER  71172480.42  C2044643633            0.0
# 3946920   286  TRANSFER  69886731.30  C1425667947            0.0
# 3911956   284  TRANSFER  69337316.27  C1584456031            0.0
# ...       ...       ...          ...          ...            ...
# 6362585   741  CASH_OUT         0.00   C312737633            0.0
# 6168500   554  CASH_OUT         0.00    C10965156            0.0
# 5563714   387  CASH_OUT         0.00  C1294472700            0.0
# 6296015   671  CASH_OUT         0.00  C1960007029            0.0
# 6281483   646  CASH_OUT         0.00  C2060908932            0.0
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 3686583             0.0   C439737079    9.595980e+03    9.245511e+07        0
# ...

# %%
#Display distinct number of transaction types
print(df_amount["type"].value_counts())
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
#Display only Fraudulent transaction
df_fraud = df[df["isFraud"] == 1]
print(df_fraud)
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 251         1  TRANSFER     2806.00  C1420196421        2806.00
# 252         1  CASH_OUT     2806.00  C2101527076        2806.00
# 680         1  TRANSFER    20128.00   C137533655       20128.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# ...

# %%
# Display distinct transcation types associated with fraud
print(df_fraud["type"].unique())
# Out:
# ['TRANSFER' 'CASH_OUT']

# %%
#Display those transactions that are flagged Fraudulent
df_flagged = df[df["isFlaggedFraud"] == 1]
print(df_flagged)
# Out:
#          step      type       amount     nameOrig  oldbalanceOrg  \
# 2736446   212  TRANSFER   4953893.08   C728984460     4953893.08
# 3247297   250  TRANSFER   1343002.08  C1100582606     1343002.08
# 3760288   279  TRANSFER    536624.41  C1035541766      536624.41
# 5563713   387  TRANSFER   4892193.09   C908544136     4892193.09
# 5996407   425  TRANSFER  10000000.00   C689608084    19585040.37
# 5996409   425  TRANSFER   9585040.37   C452586515    19585040.37
# 6168499   554  TRANSFER   3576297.10   C193696150     3576297.10
# 6205439   586  TRANSFER    353874.22  C1684585475      353874.22
# 6266413   617  TRANSFER   2542664.27   C786455622     2542664.27
# 6281482   646  TRANSFER  10000000.00    C19004745    10399045.08
# 6281484   646  TRANSFER    399045.08   C724693370    10399045.08
# 6296014   671  TRANSFER   3441041.46   C917414431     3441041.46
# 6351225   702  TRANSFER   3171085.59  C1892216157     3171085.59
# ...

# %%
#Display transactions that were Fraudulent but not flagged as fraud
df_notFlagged_isFraud = df[(df["isFraud"] == 1) & (df["isFlaggedFraud"] == 0)]
print(df_notFlagged_isFraud)
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 251         1  TRANSFER     2806.00  C1420196421        2806.00
# 252         1  CASH_OUT     2806.00  C2101527076        2806.00
# 680         1  TRANSFER    20128.00   C137533655       20128.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 2                   0.0   C553264065            0.00            0.00        1
# ...

# %%
#Display transactions not flagged as Fraud 
df_notFlagged = df[df["isFlaggedFraud"] != 1]
print(df_notFlagged)
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
#print the valuecount of th type column
print(df.value_counts("type"))
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
#Filtered results for the merchant 
df_merchant = df[df["nameDest"].str.contains("M", na=False)]
print(df_merchant)
# Out:
#          step     type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1  PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1           1  PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 4           1  PAYMENT  11668.14  C2048537720        41554.0        29885.86
# 5           1  PAYMENT   7817.71    C90045638        53860.0        46042.29
# 6           1  PAYMENT   7107.77   C154988899       183195.0       176087.23
# ...       ...      ...       ...          ...            ...             ...
# 6362312   718  PAYMENT   8178.01  C1213413071        11742.0         3563.99
# 6362314   718  PAYMENT  17841.23  C1045048098        10182.0            0.00
# 6362316   718  PAYMENT   1022.91  C1203084509           12.0            0.00
# 6362318   718  PAYMENT   4109.57   C673558958         5521.0         1411.43
# 6362319   718  PAYMENT   8634.29   C642813806       518802.0       510167.71
#
# ...

# %%
#Display the transaction type of the merchant payment
print(df_merchant["type"].unique())
# Out:
# ['PAYMENT']

# %%
#display the merchant 
print(df[df["nameDest"].str.contains("M", na=False)])
# Out:
#          step     type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0           1  PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1           1  PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 4           1  PAYMENT  11668.14  C2048537720        41554.0        29885.86
# 5           1  PAYMENT   7817.71    C90045638        53860.0        46042.29
# 6           1  PAYMENT   7107.77   C154988899       183195.0       176087.23
# ...       ...      ...       ...          ...            ...             ...
# 6362312   718  PAYMENT   8178.01  C1213413071        11742.0         3563.99
# 6362314   718  PAYMENT  17841.23  C1045048098        10182.0            0.00
# 6362316   718  PAYMENT   1022.91  C1203084509           12.0            0.00
# 6362318   718  PAYMENT   4109.57   C673558958         5521.0         1411.43
# 6362319   718  PAYMENT   8634.29   C642813806       518802.0       510167.71
#
# ...

# %% [markdown]
# ### Observations
#
# - There are no missing values in the dataset, signifying a complete dataset where every record contains information on all recorded variables.
# - There are no duplicate values in the dataset, meaning no redundancy in the dataset.
# - There are five distinct types of transaction, with "Cash_out" as the most type of transaction used by users.
# - The "Merchant" pre-transaction and post-transaction balances were not recorded.
# - The "Payment" is the only transaction type used to pay the merchants.
# - Fraud labels are available, making this dataset useful for supervised learning problems.
# - Some transactions that were fraudulent were not flagged as fraudulent.
# - There is a pattern to how fraud transactions are carried out.
# - All fraudulent transactions first transfer the amount out, and this doesn't get captured in the destination account.
# - After the fraudulent transfer, a cashout is made.

# %% [markdown]
# ### 10 Business Questions
# - Are there a specific "step" when fraudlent transactions occur?
# - Which "type" of transaction is most fraudulent ?
# - Do certain transaction type dominate transaction volumne?
# - Are high-value transaction considered to be more fraudlent?
# - Are there unusal balance patterns that are associated with fraud?
# - Do some unusal transactions get flagged as fraud?
# -  Are all fraudlent transaction really flagged as fraud?

# %% [markdown]
# ### Recommendations
# - Before model development, perform exploratory data analysis to understand the transaction distribution.
# - Build dashboards to track transaction volume and fraud trends.
# - Validate whether synthetic transaction behavior aligns with production systems.
